# %% [markdown]
# # 機器學習百日馬拉松 Day1

# %% [markdown]
# 作業一、從kaggle選擇一筆資料：Heart Disease UCI
#
# 1.這組資料為何重要
# 這組資料是Cleveland病人資料庫，有病人的幾種健康資料和心臟病的程度，可以透過建模的方式，從各種不同的變數觀察出心臟病的病發程度，若是能夠成功預測，對於未來心臟病的防範會很有幫助。
#
# 2.資料從何而來
#
# Creators:
# Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
# University Hospital, Zurich, Switzerland: William Steinbrunn, M.D.
# University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D.
# V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
#
# Donor:
# David W. Aha
#
# 3.搜集而來的資料型態
# 這是一個結構化的資料，共有14個變數，各個變數代表著病人的資訊，像是年齡、性別、血壓、胸痛類型等等
#
# 4.這組資料想解決的問題如何評估
# 主軸是要了解各個變數會佔影響心臟病的發作多大的部分，用所有變數的權重來判斷新的病人會有心臟病的可能性。可以將資料切成80%訓練資料20%測試資料，用訓練資料建立一套模型，再透過測試資料去確認模型的準確度。

# %% [markdown]
# 作業二、想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 假設：在什麼時間會有更多的乘客，在那段時間更頻繁的載客
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我會想要透過提升載客數來提升業績，可以用熱門地點和熱門的搭車時間，將司機都集中在較熱門的地點和時段服務乘客，並且避開較容易塞車路段，節省每一段的載客時間，提升載客數
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 各個司機在平時載客時就搜集客人上下車地點、時間、車資、路線、塞車狀況等資訊
#
# 3.蒐集而來的資料型態為何
# 結構化的資料表，有客人編號、上車時間、上車地點、下車時間、下車地點、車資、搭乘時間、路線、路況等變數
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 透過上述搜集的資料，能夠整理分析出搭車的尖峰時段以及熱門的載客區域，透過每週或每月的總車資變動，評估是否有達到提升業績的狀況

# %% [markdown]
# 作業三、MSE的函式
# 這是機器學習的幾種指標
# 常見於迴歸問題的評估指標
# Mean Absolute Error (MAE) 平均絕對誤差
# Mean Squared Error (MSE) 均方誤差
#
# 常見於分類問題的指標
# Binary Cross Entropy (CE) 交叉熵

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
#linspace用法是(最小數, 最大數, 數列大小)，會生成一個等差數列
x_lin = np.linspace(0, 100, 101)
#random.randn用來產生一個101筆資料的一維數列，整個計算讓y數列和x有一些相關
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MSE
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 224.992
